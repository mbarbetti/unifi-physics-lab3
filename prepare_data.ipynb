# %%
YEAR = 2023

# %%
import os
import numpy as np
import pandas as pd

from datetime import datetime
from utils import data_processing

# %%
from urllib.request import urlopen

file = urlopen(f"https://raw.githubusercontent.com/mbarbetti/unifi-physics-lab3/main/data/2021/data_A1.txt")

#list_data = list()
#for line in file:
# list_data . append (line.decode("utf-8"))

#print (len(list_data))

# %%
files_path = f"data/private/{YEAR}_original"
export_path = f"data/{YEAR}"

df = data_processing (files_path, export_path, tdc_resolution = 2e-9)
df
# Out:
#    Group  TDC resolution       theta_0   theta_1
# 0     M1    1.000000e-09  2.257065e-08  0.979785
# 1     B2    1.000000e-09 -7.782111e-08  0.964943
# 2     H2    1.000000e-09 -5.105923e-08  1.145581
# 3     G1    1.000000e-09 -6.576163e-08  1.043212
# 4     A2    1.000000e-09 -1.777116e-08  1.158012
# 5     N1    1.000000e-09  4.721098e-08  1.158455
# 6     D1    1.000000e-09 -3.544560e-08  0.979601
# 7     E2    1.000000e-09  9.735311e-08  1.087785
# 8     I1    1.000000e-09  8.471486e-09  1.137453
# 9     C1    1.000000e-09 -6.901195e-08  0.920230
# 10    L2    1.000000e-09 -1.685855e-08  0.824570
# 11    T2    1.000000e-09 -7.009671e-08  1.116873
# 12    G2    1.000000e-09 -1.304252e-08  1.116803
# 13    H1    1.000000e-09 -5.472650e-08  0.999573
# 14    B1    1.000000e-09 -8.768473e-08  1.078584
# 15    M2    1.000000e-09  5.229537e-08  1.090799
# 16    D2    1.000000e-09  2.266700e-08  1.110875
# 17    N2    1.000000e-09 -8.057764e-08  1.041289
# 18    A1    1.000000e-09  1.306051e-08  0.847790
# 19    E1    1.000000e-09  5.787667e-09  0.856219
# 20    L1    1.000000e-09  6.066219e-08  1.158346
# 21    C2    1.000000e-09 -8.939215e-09  0.912728
# 22    I2    1.000000e-09 -3.708452e-08  1.166748
# 23    T1    1.000000e-09 -5.922482e-08  1.019068

# %%
timestamp = str (datetime.now()) . split (".") [0]
timestamp = timestamp . replace (" ","_")
version = ""
for time, unit in zip ( timestamp.split(":"), ["h","m","s"] ):
  version += time + unit   # YYYY-MM-DD_HHhMMmSSs

file_name = f"manipulation_{version}"

df.to_csv ( f"data/private/manipulation/{file_name}.txt", header = df.columns, index = None, sep = " " )

# %%
data = pd.read_csv ( f"{export_path}/data_M1.txt", header = 4, delim_whitespace = True).drop([0] )
data
# Out:
#             TDC          QDC1          QDC2
# 1      0.000008 -8.195830e-10 -8.299997e-10
# 2      0.000010 -8.133330e-10 -8.029163e-10
# 3      0.000008 -8.154163e-10 -8.154163e-10
# 4      0.000003 -8.174997e-10 -8.174997e-10
# 5      0.000002 -8.174997e-10 -8.195830e-10
# ...         ...           ...           ...
# 27160  0.000009 -9.636254e-09 -5.730002e-09
# 27161  0.000002 -5.309168e-09 -2.869584e-09
# 27162  0.000001 -1.927917e-09 -1.627917e-09
# 27163  0.000009 -3.444584e-09 -4.544585e-09
# 27164  0.000007 -4.634168e-09 -1.889375e-09
#
# [27164 rows x 3 columns]
